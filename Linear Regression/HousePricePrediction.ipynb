# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("sample_data/HousePricePrediction.csv")
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 15205    -117.07     33.01                 5.0       5870.0           977.0
# 15206    -117.06     33.01                 9.0       2470.0           417.0
# 15207    -117.07     33.00                 4.0       6242.0          1258.0
# 15208    -117.07     33.00                 4.0       9153.0          1866.0
# 15209    -117.08     33.01                 5.0       5659.0           931.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15210 entries, 0 to 15209
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           15210 non-null  float64
#  1   latitude            15210 non-null  float64
#  2   housing_median_age  15210 non-null  float64
#  3   total_rooms         15210 non-null  float64
#  4   total_bedrooms      15062 non-null  float64
#  5   population          15210 non-null  float64
#  6   households          15210 non-null  float64
#  7   median_income       15210 non-null  float64
#  8   median_house_value  15210 non-null  float64
#  9   ocean_proximity     15209 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.2+ MB

# %%
data.dropna(inplace=True)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 15204    -117.08     32.91                 9.0       1547.0           218.0
# 15205    -117.07     33.01                 5.0       5870.0           977.0
# 15206    -117.06     33.01                 9.0       2470.0           417.0
# 15207    -117.07     33.00                 4.0       6242.0          1258.0
# 15208    -117.07     33.00                 4.0       9153.0          1866.0
#
# ...

# %%
features = data.drop(["median_house_value"], axis=1)
target = data.loc[:,["median_house_value"]]
